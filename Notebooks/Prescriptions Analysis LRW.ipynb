# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.ensemble import RandomForestClassifier

# %%
PRESCRIPTIONS = "../../Resources/PRESCRIPTIONS.csv"
PATIENTS = "../../Resources/PATIENTS.csv"

# %%
Rx_df = pd.read_csv(PRESCRIPTIONS, low_memory=False)
Rx_df.head()
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 0  2214776           6   107064         NaN  2175-06-11 00:00:00
# 1  2214775           6   107064         NaN  2175-06-11 00:00:00
# 2  2215524           6   107064         NaN  2175-06-11 00:00:00
# 3  2216265           6   107064         NaN  2175-06-11 00:00:00
# 4  2214773           6   107064         NaN  2175-06-11 00:00:00
#
#                ENDDATE DRUG_TYPE            DRUG DRUG_NAME_POE  \
# 0  2175-06-12 00:00:00      MAIN      Tacrolimus    Tacrolimus
# 1  2175-06-12 00:00:00      MAIN        Warfarin      Warfarin
# 2  2175-06-12 00:00:00      MAIN  Heparin Sodium           NaN
# 3  2175-06-12 00:00:00      BASE             D5W           NaN
# 4  2175-06-12 00:00:00      MAIN      Furosemide    Furosemide
#
#   DRUG_NAME_GENERIC FORMULARY_DRUG_CD     GSN          NDC  \
# 0        Tacrolimus             TACR1  021796  469061711.0
# 1          Warfarin             WARF5  006562   56017275.0
# ...

# %%
Rx_df['DRUG'].value_counts()
# Out:
# Potassium Chloride                192993
# Insulin                           143465
# D5W                               142241
# Furosemide                        133122
# 0.9% Sodium Chloride              130147
# NS                                129731
# Magnesium Sulfate                  90427
# Iso-Osmotic Dextrose               87005
# Sodium Chloride 0.9%  Flush        83392
# Acetaminophen                      78768
# Metoprolol                         73986
# 5% Dextrose                        73829
# SW                                 72522
# Morphine Sulfate                   62134
# Metoprolol Tartrate                59824
# Lorazepam                          55352
# Calcium Gluconate                  52110
# Heparin                            52069
# Docusate Sodium                    45694
# Vancomycin                         42634
# Bisacodyl                          41075
# Warfarin                           39678
# Heparin Sodium                     37702
# ...

# %%
#Rx_df['DRUG'].hist()

# %%
Rx_df['DRUG'].describe()
# Out:
# count                4156450
# unique                  4525
# top       Potassium Chloride
# freq                  192993
# Name: DRUG, dtype: object

# %%
patient_df = pd.read_csv(PATIENTS)

patient_df = patient_df.drop(['ROW_ID'], axis=1)

patient_df.head()
# Out:
#    SUBJECT_ID GENDER                  DOB                  DOD  \
# 0         249      F  2075-03-13 00:00:00                  NaN
# 1         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2         251      M  2090-03-15 00:00:00                  NaN
# 3         252      M  2078-03-06 00:00:00                  NaN
# 4         253      F  2089-11-26 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0
# 3                  NaN     NaN            0
# 4                  NaN     NaN            0

# %%
Rx_joined = Rx_df.merge(patient_df, on='SUBJECT_ID')

Rx_joined.head()
#print(join_df.DESCR)
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTDATE  \
# 0  2214776           6   107064         NaN  2175-06-11 00:00:00
# 1  2214775           6   107064         NaN  2175-06-11 00:00:00
# 2  2215524           6   107064         NaN  2175-06-11 00:00:00
# 3  2216265           6   107064         NaN  2175-06-11 00:00:00
# 4  2214773           6   107064         NaN  2175-06-11 00:00:00
#
#                ENDDATE DRUG_TYPE            DRUG DRUG_NAME_POE  \
# 0  2175-06-12 00:00:00      MAIN      Tacrolimus    Tacrolimus
# 1  2175-06-12 00:00:00      MAIN        Warfarin      Warfarin
# 2  2175-06-12 00:00:00      MAIN  Heparin Sodium           NaN
# 3  2175-06-12 00:00:00      BASE             D5W           NaN
# 4  2175-06-12 00:00:00      MAIN      Furosemide    Furosemide
#
#   DRUG_NAME_GENERIC     ...     DOSE_UNIT_RX FORM_VAL_DISP  FORM_UNIT_DISP  \
# 0        Tacrolimus     ...               mg             2             CAP
# ...

# %%
target = Rx_joined["EXPIRE_FLAG"]
target_names = ["negative", "positive"]

# %%
data1 = Rx_joined.drop(["EXPIRE_FLAG", 'STARTDATE'], axis=1)

# %%
data = data1.drop(["ENDDATE", 'DOB'], axis=1)
feature_names = data.columns
pd.set_option('display.max_columns', 60)
data.head()
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID DRUG_TYPE            DRUG  \
# 0  2214776           6   107064         NaN      MAIN      Tacrolimus
# 1  2214775           6   107064         NaN      MAIN        Warfarin
# 2  2215524           6   107064         NaN      MAIN  Heparin Sodium
# 3  2216265           6   107064         NaN      BASE             D5W
# 4  2214773           6   107064         NaN      MAIN      Furosemide
#
#   DRUG_NAME_POE DRUG_NAME_GENERIC FORMULARY_DRUG_CD     GSN          NDC  \
# 0    Tacrolimus        Tacrolimus             TACR1  021796  469061711.0
# 1      Warfarin          Warfarin             WARF5  006562   56017275.0
# 2           NaN               NaN        HEPAPREMIX  006522  338055002.0
# 3           NaN               NaN           HEPBASE     NaN          0.0
# 4    Furosemide        Furosemide            FURO20  008208   54829725.0
#
#             PROD_STRENGTH DOSE_VAL_RX DOSE_UNIT_RX FORM_VAL_DISP  \
# ...

# %%
type(data.DRUG[1])
# Out:
# str

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-919dfd680ef1> in <module>()
# ----> 1 clf = tree.DecisionTreeClassifier()
#       2 clf = clf.fit(X_train, y_train)
#       3 clf.score(X_test, y_test)
#
# NameError: name 'tree' is not defined

# %%
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
