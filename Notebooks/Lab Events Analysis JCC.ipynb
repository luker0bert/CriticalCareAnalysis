# %%
import pandas as pd

# %%
LABEVENTS = "../../Resources/LABEVENTS.csv"
D_LABITEMS = "../../Resources/D_LABITEMS.csv"
PATIENTS = "../../Resources/PATIENTS.csv"

# %%
lab_df = pd.read_csv(LABEVENTS)

lab_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ITEMID            CHARTTIME VALUE  VALUENUM  \
# 0     281           3      NaN   50820  2101-10-12 16:07:00  7.39      7.39
# 1     282           3      NaN   50800  2101-10-12 18:17:00   ART       NaN
# 2     283           3      NaN   50802  2101-10-12 18:17:00    -1     -1.00
# 3     284           3      NaN   50804  2101-10-12 18:17:00    22     22.00
# 4     285           3      NaN   50808  2101-10-12 18:17:00  0.93      0.93
#
#   VALUEUOM      FLAG
# 0    units       NaN
# 1      NaN       NaN
# 2    mEq/L       NaN
# 3    mEq/L       NaN
# 4   mmol/L  abnormal

# %%
items_df = pd.read_csv(D_LABITEMS)

items_df = items_df.drop(['ROW_ID'], axis=1)

items_df.head()
# Out:
#    ITEMID                       LABEL                      FLUID    CATEGORY  \
# 0   51346                      Blasts  Cerebrospinal Fluid (CSF)  Hematology
# 1   51347                 Eosinophils  Cerebrospinal Fluid (CSF)  Hematology
# 2   51348             Hematocrit, CSF  Cerebrospinal Fluid (CSF)  Hematology
# 3   51349  Hypersegmented Neutrophils  Cerebrospinal Fluid (CSF)  Hematology
# 4   51350           Immunophenotyping  Cerebrospinal Fluid (CSF)  Hematology
#
#   LOINC_CODE
# 0    26447-3
# 1    26451-5
# 2    30398-2
# 3    26506-6
# 4        NaN

# %%
joined_df = lab_df.merge(items_df, on='ITEMID')

joined_df.head()
# Out:
#    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME VALUE  VALUENUM  \
# 0     281           3       NaN   50820  2101-10-12 16:07:00  7.39      7.39
# 1     289           3       NaN   50820  2101-10-12 18:17:00  7.42      7.42
# 2     396           3       NaN   50820  2101-10-15 12:42:00  7.49      7.49
# 3     976           3  145834.0   50820  2101-10-22 04:31:00  7.40      7.40
# 4     989           3  145834.0   50820  2101-10-22 07:13:00  7.37      7.37
#
#   VALUEUOM FLAG LABEL  FLUID   CATEGORY LOINC_CODE
# 0    units  NaN    pH  Blood  Blood Gas    11558-4
# 1    units  NaN    pH  Blood  Blood Gas    11558-4
# 2    units  NaN    pH  Blood  Blood Gas    11558-4
# 3    units  NaN    pH  Blood  Blood Gas    11558-4
# 4    units  NaN    pH  Blood  Blood Gas    11558-4

# %%
joined_df['FLUID'].value_counts()
# Out:
# Blood                        25341470
# Urine                         1964068
# BLOOD                          405141
# Cerebrospinal Fluid (CSF)       35917
# Ascites                         31224
# Pleural                         28393
# Other Body Fluid                24667
# URINE                           11850
# Bone Marrow                      5368
# Joint Fluid                      5319
# Stool                             630
# OTHER BODY FLUID                    6
# JOINT FLUID                         2
# Name: FLUID, dtype: int64

# %%
patient_df = pd.read_csv(PATIENTS)

patient_df = patient_df.drop(['ROW_ID'], axis=1)

patient_df.head()
# Out:
#    SUBJECT_ID GENDER                  DOB                  DOD  \
# 0         249      F  2075-03-13 00:00:00                  NaN
# 1         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2         251      M  2090-03-15 00:00:00                  NaN
# 3         252      M  2078-03-06 00:00:00                  NaN
# 4         253      F  2089-11-26 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0
# 3                  NaN     NaN            0
# 4                  NaN     NaN            0

# %%
final_df = joined_df.merge(patient_df, on='SUBJECT_ID')

final_df.head()
# Out:
#    ROW_ID  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME VALUE
# 12            7.39    units       NaN                   pH  Blood   Blood Gas
# 13            7.42    units       NaN                   pH  Blood   Blood Gas
# 14            7.37    units       NaN                   pH  Blood   Blood Gas
# 15            7.39    units       NaN                   pH  Blood   Blood Gas
# 16            7.26    units       NaN                   pH  Blood   Blood Gas
# 17            7.26    units       NaN                   pH  Blood   Blood Gas
# 18            7.29    units       NaN                   pH  Blood   Blood Gas
# 19            7.30    units       NaN                   pH  Blood   Blood Gas
# 20            7.35    units       NaN                   pH  Blood   Blood Gas
# 21            7.59    units       NaN                   pH  Blood   Blood Gas
# 22            7.44    units       NaN                   pH  Blood   Blood Gas
# 23            7.43    units       NaN                   pH  Blood   Blood Gas
# 24            7.39    units       NaN                   pH  Blood   Blood Gas
# 25            7.40    units       NaN                   pH  Blood   Blood Gas
# 26            7.37    units       NaN                   pH  Blood   Blood Gas
# 27            7.31    units  abnormal                   pH  Blood   Blood Gas
# 28            7.41    units       NaN                   pH  Blood   Blood Gas
# 29            7.33    units       NaN                   pH  Blood   Blood Gas
# ...            ...      ...       ...                  ...    ...         ...
# 27854019    487.00     #/uL       NaN   CD5 Absolute Count  Blood  Hematology
# 27854020    314.00     #/uL       NaN   CD5 Absolute Count  Blood  Hematology
# 27854021    293.00     #/uL       NaN   CD5 Absolute Count  Blood  Hematology
# 27854022    392.00     #/uL       NaN   CD5 Absolute Count  Blood  Hematology
# 27854023    606.00     #/uL       NaN   CD5 Absolute Count  Blood  Hematology
# 27854024       NaN      NaN       NaN                  TdT  Blood  Hematology
# 27854025       NaN      NaN       NaN                  TdT  Blood  Hematology
# 27854026       NaN      NaN       NaN                  TdT  Blood  Hematology
# 27854027       NaN      NaN       NaN                  TdT  Blood  Hematology
# 27854028       NaN      NaN       NaN                  TdT  Blood  Hematology
# 27854029       NaN      NaN       NaN                  TdT  Blood  Hematology
# 27854030       NaN      NaN       NaN                  TdT  Blood  Hematology
# 27854031       NaN      NaN       NaN                  TdT  Blood  Hematology
# 27854032       NaN      NaN       NaN                  TdT  Blood  Hematology
# 27854039      5.00        %       NaN               CD19 %  Blood  Hematology
# 27854040      0.46        %       NaN               CD19 %  Blood  Hematology
# 27854041      5.00        %       NaN               CD19 %  Blood  Hematology
# 27854042      0.00        %       NaN               CD19 %  Blood  Hematology
# 27854043     13.00     #/uL       NaN  CD19 Absolute Count  Blood  Hematology
# 27854044      3.00     #/uL       NaN  CD19 Absolute Count  Blood  Hematology
# 27854045     16.00     #/uL       NaN  CD19 Absolute Count  Blood  Hematology
# 27854046      0.00     #/uL       NaN  CD19 Absolute Count  Blood  Hematology
# 27854047      5.00        %       NaN               CD20 %  Blood  Hematology
# 27854048      0.23        %       NaN               CD20 %  Blood  Hematology
# 27854049      0.00        %       NaN               CD20 %  Blood  Hematology
# 27854050      0.00        %       NaN               CD20 %  Blood  Hematology
# 27854051     13.00     #/uL       NaN  CD20 Absolute Count  Blood  Hematology
# 27854052      2.00     #/uL       NaN  CD20 Absolute Count  Blood  Hematology
# 27854053      0.00     #/uL       NaN  CD20 Absolute Count  Blood  Hematology
# 27854054      0.00     #/uL       NaN  CD20 Absolute Count  Blood  Hematology
#
#          LOINC_CODE
# 0           11558-4
# 1           11558-4
# 2           11558-4
# 3           11558-4
# 4           11558-4
# 5           11558-4
# 6           11558-4
# 7           11558-4
# 8           11558-4
# 9           11558-4
# 10          11558-4
# 11          11558-4
# 12          11558-4
# 13          11558-4
# 14          11558-4
# 15          11558-4
# 16          11558-4
# 17          11558-4
# 18          11558-4
# 19          11558-4
# 20          11558-4
# 21          11558-4
# 22          11558-4
# 23          11558-4
# 24          11558-4
# 25          11558-4
# 26          11558-4
# 27          11558-4
# 28          11558-4
# 29          11558-4
# ...             ...
# 27854019        NaN
# 27854020        NaN
# 27854021        NaN
# 27854022        NaN
# 27854023        NaN
# 27854024        NaN
# 27854025        NaN
# 27854026        NaN
# 27854027        NaN
# 27854028        NaN
# 27854029        NaN
# 27854030        NaN
# 27854031        NaN
# 27854032        NaN
# 27854039        NaN
# 27854040        NaN
# 27854041        NaN
# 27854042        NaN
# 27854043        NaN
# 27854044        NaN
# 27854045        NaN
# 27854046        NaN
# 27854047        NaN
# 27854048        NaN
# 27854049        NaN
# 27854050        NaN
# 27854051        NaN
# 27854052        NaN
# 27854053        NaN
# 27854054        NaN
#
# [25341470 rows x 13 columns]

# %%
# Blood Gas labels
blood_gas = blood_df[blood_df.CATEGORY == 'Blood Gas']
blood_gas = blood_gas[['SUBJECT_ID','HADM_ID','CHARTTIME','FLAG','LABEL','CATEGORY']]
blood_gas.to_csv("../../../blood_gas.csv")
#blood_gas_chloride = blood_gas[blood_gas.LABEL == 'Chloride, Whole Blood']
#blood_gas_glucose = blood_gas[blood_gas.LABEL == 'Glucose']
#blood_gas_hematocritcalc = blood_gas[blood_gas.LABEL == 'Hematocrit, Calculated']
#blood_gas_hemoglobin = blood_gas[blood_gas.LABEL == 'Hemoglobin']
#blood_gas_lactate = blood_gas[blood_gas.LABEL == 'Lactate']
#blood_gas_potassiumwb = blood_gas[blood_gas.LABEL == 'Potassium, Whole Blood']
#blood_gas_sodiumwb = blood_gas[blood_gas.LABEL == 'Sodium, Whole Blood']

# %%
# Chemistry labels
chemistry = blood_df[blood_df.CATEGORY == 'Chemistry']
chemistry = chemistry[['SUBJECT_ID','HADM_ID','CHARTTIME','FLAG','LABEL','CATEGORY']]
chemistry.to_csv("../../../chemistry.csv")
#chemistry_anion_gap = chemistry[chemistry.LABEL == 'Anion Gap']
#chemistry_albumin = chemistry[chemistry.LABEL == 'Albumin']
#chemistry_bicarbonate = chemistry[chemistry.LABEL == 'Bicarbonate']
#chemistry_bilirubin_total = chemistry[chemistry.LABEL == 'Bilirubin, Total']
#chemistry_creatinine = chemistry[chemistry.LABEL == 'Creatinine']
#chemistry_chloride = chemistry[chemistry.LABEL == 'Chloride']
#chemistry_glucose = chemistry[chemistry.LABEL == 'Glucose']
#chemistry_magnesium = chemistry[chemistry.LABEL == 'Magnesium']
#chemistry_phosphate = chemistry[chemistry.LABEL == 'Phosphate']
#chemistry_potassium = chemistry[chemistry.LABEL == 'Potassium']
#chemistry_sodium = chemistry[chemistry.LABEL == 'Sodium']
#chemistry_urea_nitrogen = chemistry[chemistry.LABEL == 'Urea Nitrogen']

# %%
# Hematology labels
hematology = blood_df[blood_df.CATEGORY == 'Hematology']
hematology = hematology[['SUBJECT_ID','HADM_ID','CHARTTIME','FLAG','LABEL','CATEGORY']]
hematology.to_csv("../../../hematology.csv")
#hematology_hematocrit = hematology[hematology.LABEL == 'Hematocrit']
#hematology_hemoglobin = hematology[hematology.LABEL == 'Hemoglobin']
#hematology_platelet_count = hematology[hematology.LABEL == 'Platelet Count']
#hematology_ptt = hematology[hematology.LABEL == 'PTT']
#hematology_inr(pt) = hematology[hematology.LABEL == 'INR(PT)']
#hematology_pt = hematology[hematology.LABEL == 'PT']
#hematology_white_blood_cells = hematology[hematology.LABEL == 'White Blood Cells']
#hematology_wbc_count = hematology[hematology.LABEL == 'WBC Count']
