# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.ensemble import RandomForestClassifier

# %%
ADMISSIONS = "../../Resources/ADMISSIONS.csv"
PATIENTS = "../../Resources/PATIENTS.csv"
ICU_STAYS = "../../Resources/ICUSTAYS.csv"

# %%
admissions_df = pd.read_csv(ADMISSIONS)
patients_df = pd.read_csv(PATIENTS)
icu_df = pd.read_csv(ICU_STAYS)

# %%
admissions_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3      24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4      25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 4       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
#
#           DISCHARGE_LOCATION INSURANCE LANGUAGE           RELIGION  \
# 0  DISC-TRAN CANCER/CHLDRN H   Private      NaN       UNOBTAINABLE
# ...

# %%
admissions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58976 entries, 0 to 58975
# Data columns (total 19 columns):
# ROW_ID                  58976 non-null int64
# SUBJECT_ID              58976 non-null int64
# HADM_ID                 58976 non-null int64
# ADMITTIME               58976 non-null object
# DISCHTIME               58976 non-null object
# DEATHTIME               5854 non-null object
# ADMISSION_TYPE          58976 non-null object
# ADMISSION_LOCATION      58976 non-null object
# DISCHARGE_LOCATION      58976 non-null object
# INSURANCE               58976 non-null object
# LANGUAGE                33644 non-null object
# RELIGION                58518 non-null object
# MARITAL_STATUS          48848 non-null object
# ETHNICITY               58976 non-null object
# EDREGTIME               30877 non-null object
# EDOUTTIME               30877 non-null object
# DIAGNOSIS               58951 non-null object
# HOSPITAL_EXPIRE_FLAG    58976 non-null int64
# ...

# %%
admissions_clean = admissions_df.dropna()
admissions_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2053 entries, 193 to 58972
# Data columns (total 19 columns):
# ROW_ID                  2053 non-null int64
# SUBJECT_ID              2053 non-null int64
# HADM_ID                 2053 non-null int64
# ADMITTIME               2053 non-null object
# DISCHTIME               2053 non-null object
# DEATHTIME               2053 non-null object
# ADMISSION_TYPE          2053 non-null object
# ADMISSION_LOCATION      2053 non-null object
# DISCHARGE_LOCATION      2053 non-null object
# INSURANCE               2053 non-null object
# LANGUAGE                2053 non-null object
# RELIGION                2053 non-null object
# MARITAL_STATUS          2053 non-null object
# ETHNICITY               2053 non-null object
# EDREGTIME               2053 non-null object
# EDOUTTIME               2053 non-null object
# DIAGNOSIS               2053 non-null object
# HOSPITAL_EXPIRE_FLAG    2053 non-null int64
# ...

# %%
patients_df.head()
# Out:
#    ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0     234         249      F  2075-03-13 00:00:00                  NaN
# 1     235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2     236         251      M  2090-03-15 00:00:00                  NaN
# 3     237         252      M  2078-03-06 00:00:00                  NaN
# 4     238         253      F  2089-11-26 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0
# 3                  NaN     NaN            0
# 4                  NaN     NaN            0

# %%
patients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46520 entries, 0 to 46519
# Data columns (total 8 columns):
# ROW_ID         46520 non-null int64
# SUBJECT_ID     46520 non-null int64
# GENDER         46520 non-null object
# DOB            46520 non-null object
# DOD            15759 non-null object
# DOD_HOSP       9974 non-null object
# DOD_SSN        13378 non-null object
# EXPIRE_FLAG    46520 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 2.8+ MB

# %%
patients_clean = patients_df.dropna()
patients_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7593 entries, 7 to 46513
# Data columns (total 8 columns):
# ROW_ID         7593 non-null int64
# SUBJECT_ID     7593 non-null int64
# GENDER         7593 non-null object
# DOB            7593 non-null object
# DOD            7593 non-null object
# DOD_HOSP       7593 non-null object
# DOD_SSN        7593 non-null object
# EXPIRE_FLAG    7593 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 533.9+ KB

# %%
icu_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID DBSOURCE FIRST_CAREUNIT  \
# 0     365         268   110404      280836  carevue           MICU
# 1     366         269   106296      206613  carevue           MICU
# 2     367         270   188028      220345  carevue            CCU
# 3     368         271   173727      249196  carevue           MICU
# 4     369         272   164716      210407  carevue            CCU
#
#   LAST_CAREUNIT  FIRST_WARDID  LAST_WARDID               INTIME  \
# 0          MICU            52           52  2198-02-14 23:27:38
# 1          MICU            52           52  2170-11-05 11:05:29
# 2           CCU            57           57  2128-06-24 15:05:20
# 3          SICU            52           23  2120-08-07 23:12:42
# 4           CCU            57           57  2186-12-25 21:08:04
#
#                OUTTIME     LOS
# 0  2198-02-18 05:26:11  3.2490
# 1  2170-11-08 17:46:57  3.2788
# 2  2128-06-27 12:32:29  2.8939
# 3  2120-08-10 00:39:04  2.0600
# ...

# %%
icu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61532 entries, 0 to 61531
# Data columns (total 12 columns):
# ROW_ID            61532 non-null int64
# SUBJECT_ID        61532 non-null int64
# HADM_ID           61532 non-null int64
# ICUSTAY_ID        61532 non-null int64
# DBSOURCE          61532 non-null object
# FIRST_CAREUNIT    61532 non-null object
# LAST_CAREUNIT     61532 non-null object
# FIRST_WARDID      61532 non-null int64
# LAST_WARDID       61532 non-null int64
# INTIME            61532 non-null object
# OUTTIME           61522 non-null object
# LOS               61522 non-null float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 5.6+ MB

# %%
icu_clean = icu_df.dropna()
icu_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61522 entries, 0 to 61531
# Data columns (total 12 columns):
# ROW_ID            61522 non-null int64
# SUBJECT_ID        61522 non-null int64
# HADM_ID           61522 non-null int64
# ICUSTAY_ID        61522 non-null int64
# DBSOURCE          61522 non-null object
# FIRST_CAREUNIT    61522 non-null object
# LAST_CAREUNIT     61522 non-null object
# FIRST_WARDID      61522 non-null int64
# LAST_WARDID       61522 non-null int64
# INTIME            61522 non-null object
# OUTTIME           61522 non-null object
# LOS               61522 non-null float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 6.1+ MB
